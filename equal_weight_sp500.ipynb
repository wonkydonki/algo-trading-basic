# %% [markdown]
# ***EQUAL-WEIGHT S&P 500 INDEX FUND***
# - first project in the three - we will make a replica of the s&p 500 but an equal weight version.
# - all the stocks have equal weight as opposed to the actual index which is weighted based on market capitalization.
# - this roject along with the two others follows along the freeCodeCamp.org course online on **Algorithmic Trading in Python**
#
# **The goal is to take as input the value of your portofolio and then return the number of shares of which company you need to purchase in order to construct a replica of the index fund**

# %% [markdown]
# **Importing our dependencies first**

# %%
import numpy as np
import pandas as pd
#!pip3 install requests
import requests
#!pip3 install xlsxwriter
import xlsxwriter

# %% [markdown]
# **Next we use import our list of stocks for the project**
